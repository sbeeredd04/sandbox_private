# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Define transformations
transform = transforms.Compose([
    transforms.Resize(64),
    transforms.CenterCrop(64),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load CelebA dataset
celeba_train = datasets.CelebA(
    root='./data',
    split='train',
    target_type='attr',
    transform=transform,
    download=True
)

# Create DataLoader
train_loader = DataLoader(celeba_train, batch_size=64, shuffle=True, num_workers=2)
# Out:
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gdown/download.py:267, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     266 try:
# --> 267     url = get_url_from_gdrive_confirmation(res.text)
#     268 except FileURLRetrievalError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gdown/download.py:53, in get_url_from_gdrive_confirmation(contents)
#      52         error = m.groups()[0]
# ---> 53         raise FileURLRetrievalError(error)
#      54 if not url:
#
# FileURLRetrievalError: Too many users have viewed or downloaded this file recently. Please try accessing the file again later. If the file you are trying to access is particularly large or is shared with many people, it may take up to 24 hours to be able to view or download the file. If you still can't access a file after 24 hours, contact your domain administrator.
#
# During handling of the above exception, another exception occurred:
#
# FileURLRetrievalError                     Traceback (most recent call last)
# Cell In[1], line 13
#       5 transform = transforms.Compose([
#       6     transforms.Resize(64),
#       7     transforms.CenterCrop(64),
#       8     transforms.ToTensor(),
#       9     transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
#      10 ])
#      12 # Load CelebA dataset
# ---> 13 celeba_train = datasets.CelebA(
#      14     root='./data',
#      15     split='train',
#      16     target_type='attr',
#      17     transform=transform,
#      18     download=True
#      19 )
#      21 # Create DataLoader
#      22 train_loader = DataLoader(celeba_train, batch_size=64, shuffle=True, num_workers=2)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/celeba.py:85, in CelebA.__init__(self, root, split, target_type, transform, target_transform, download)
#      82     raise RuntimeError("target_transform is specified but target_type is empty")
#      84 if download:
# ---> 85     self.download()
#      87 if not self._check_integrity():
#      88     raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/celeba.py:155, in CelebA.download(self)
#     152     return
#     154 for (file_id, md5, filename) in self.file_list:
# --> 155     download_file_from_google_drive(file_id, os.path.join(self.root, self.base_folder), filename, md5)
#     157 extract_archive(os.path.join(self.root, self.base_folder, "img_align_celeba.zip"))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/datasets/utils.py:210, in download_file_from_google_drive(file_id, root, filename, md5)
#     207     print(f"Using downloaded {'and verified ' if md5 else ''}file: {fpath}")
#     208     return
# --> 210 gdown.download(id=file_id, output=fpath, quiet=False, user_agent=USER_AGENT)
#     212 if not check_integrity(fpath, md5):
#     213     raise RuntimeError("File not found or corrupted.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gdown/download.py:278, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     268     except FileURLRetrievalError as e:
#     269         message = (
#     270             "Failed to retrieve file url:\n\n{}\n\n"
#     271             "You may still be able to access the file from the browser:"
#    (...)
#     276             url_origin,
#     277         )
# --> 278         raise FileURLRetrievalError(message)
#     280 filename_from_url = None
#     281 last_modified_time = None
#
# FileURLRetrievalError: Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
#
# but Gdown can't. Please check connections and permissions.
